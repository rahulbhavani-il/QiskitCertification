# %% [markdown]
# # Single-Qubit Gates - Code Laboratory
#
# **Section 1: Quantum Operations | Part 1 of 3**
#
# > 📖 **For concepts, analogies, and theory**: See [README.md](README.md)
# > 🔬 **This notebook**: Executable code demonstrations and API exploration
#
# ---
#
# ## 🚀 Quick API Reference
#
# | Gate | Qiskit Method | Parameters | Effect |
# |------|---------------|------------|--------|
# | **X** | `qc.x(qubit)` | qubit: int | Bit flip: \|0⟩↔\|1⟩ |
# | **Y** | `qc.y(qubit)` | qubit: int | Bit+phase flip |
# | **Z** | `qc.z(qubit)` | qubit: int | Phase flip: \|1⟩→-\|1⟩ |
# | **H** | `qc.h(qubit)` | qubit: int | Superposition creator |
# | **S** | `qc.s(qubit)` | qubit: int | Phase π/2 |
# | **S†** | `qc.sdg(qubit)` | qubit: int | Phase -π/2 |
# | **T** | `qc.t(qubit)` | qubit: int | Phase π/4 |
# | **T†** | `qc.tdg(qubit)` | qubit: int | Phase -π/4 |
# | **P** | `qc.p(λ, qubit)` | λ: float, qubit: int | Phase λ |
# | **RX** | `qc.rx(θ, qubit)` | θ: float, qubit: int | X-rotation |
# | **RY** | `qc.ry(θ, qubit)` | θ: float, qubit: int | Y-rotation |
# | **RZ** | `qc.rz(θ, qubit)` | θ: float, qubit: int | Z-rotation |
#
# ---
#
# ## 📋 Notebook Contents
#
# 1. **Setup** - Imports and helper functions
# 2. **Pauli Gates** - X, Y, Z demonstrations
# 3. **Hadamard Gate** - Superposition creation
# 4. **Phase Gates** - S, T, P demonstrations
# 5. **Rotation Gates** - RX, RY, RZ demonstrations
# 6. **Pauli Class** - `qiskit.quantum_info.Pauli` API
# 7. **Trap Demonstrations** - Common mistakes in code
# 8. **Code Challenges** - Test your understanding
#
# ---

# %% [markdown]
# ## 1. Setup
#
# Import required libraries and define helper functions:

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator, Pauli
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# %matplotlib inline

# Helper function: verify gate output
def verify_gate(qc, expected_state, gate_name="Gate"):
    """Verify gate produces expected state vector."""
    actual = Statevector(qc).data
    match = np.allclose(actual, expected_state, atol=1e-10)
    status = "✅ PASS" if match else "❌ FAIL"
    print(f"{gate_name}: {status}")
    print(f"  Expected: {expected_state}")
    print(f"  Actual:   {actual}")
    return match

# Helper function: show gate matrix
def show_matrix(qc, name="Gate"):
    """Display gate matrix."""
    matrix = Operator(qc).data
    print(f"{name} Matrix:")
    print(np.round(matrix, 4))
    return matrix

print("✅ Setup complete - all imports successful!")

# %% [markdown]
# ---
#
# ## 2. Pauli Gates (X, Y, Z)
#
# ### API Reference
# ```python
# qc.x(qubit)  # X gate (bit flip)
# qc.y(qubit)  # Y gate (bit + phase flip)
# qc.z(qubit)  # Z gate (phase flip)
# ```
#
# > 📖 Theory: See README.md for matrices and Bloch sphere rotations

# %%
# Pauli Gates - X, Y, Z

# X Gate (Bit Flip): |0⟩↔|1⟩
qc_x = QuantumCircuit(1)
qc_x.x(0)
show_matrix(qc_x, "X")
verify_gate(qc_x, [0, 1], "X|0⟩ → |1⟩")

# Y Gate: |0⟩→i|1⟩
qc_y = QuantumCircuit(1)
qc_y.y(0)
show_matrix(qc_y, "\nY")
verify_gate(qc_y, [0, 1j], "Y|0⟩ → i|1⟩")

# Z Gate (Phase Flip): |0⟩→|0⟩, |1⟩→-|1⟩
qc_z = QuantumCircuit(1)
qc_z.z(0)
show_matrix(qc_z, "\nZ")
verify_gate(qc_z, [1, 0], "Z|0⟩ → |0⟩ (UNCHANGED!)")

# Z on |1⟩ 
qc_z1 = QuantumCircuit(1)
qc_z1.x(0)
qc_z1.z(0)
verify_gate(qc_z1, [0, -1], "Z|1⟩ → -|1⟩")

# Self-inverse property: X² = Y² = Z² = I
print("\n--- Self-inverse Verification ---")
for gate_name, gate_method in [('X', 'x'), ('Y', 'y'), ('Z', 'z')]:
    qc = QuantumCircuit(1)
    getattr(qc, gate_method)(0)
    getattr(qc, gate_method)(0)
    state = Statevector(qc)
    is_identity = np.allclose(state.data, [1, 0])
    print(f"{gate_name}² = I: {'✅' if is_identity else '❌'}")

# %% [markdown]
# ---
#
# ## 3. Hadamard Gate (H)
#
# ### API Reference
# ```python
# qc.h(qubit)  # Hadamard gate
# ```
#
# > 📖 Theory: H creates superposition. H|0⟩=|+⟩, H|1⟩=|-⟩, H²=I

# %%
# Hadamard Gate - Creates superposition

# H|0⟩ = |+⟩
qc_h = QuantumCircuit(1)
qc_h.h(0)
show_matrix(qc_h, "H")
plus_state = [1/np.sqrt(2), 1/np.sqrt(2)]
verify_gate(qc_h, plus_state, "H|0⟩ → |+⟩")

# H|1⟩ = |-⟩
qc_h1 = QuantumCircuit(1)
qc_h1.x(0)
qc_h1.h(0)
minus_state = [1/np.sqrt(2), -1/np.sqrt(2)]
verify_gate(qc_h1, minus_state, "H|1⟩ → |-⟩")

# H² = I (self-inverse)
qc_h2 = QuantumCircuit(1)
qc_h2.h(0)
qc_h2.h(0)
verify_gate(qc_h2, [1, 0], "H²|0⟩ → |0⟩ (self-inverse)")

# HXH = Z (conjugation)
qc_hxh = QuantumCircuit(1)
qc_hxh.h(0)
qc_hxh.x(0)
qc_hxh.h(0)
qc_z_only = QuantumCircuit(1)
qc_z_only.z(0)
print(f"\nHXH = Z: {np.allclose(Operator(qc_hxh).data, Operator(qc_z_only).data)} ✅")

# %%
# Hadamard Conjugation Identities: HXH = Z and HZH = X
print("Hadamard Conjugation Identities")
print("=" * 50)

from qiskit.quantum_info import Operator

# HXH = Z
qc_hxh = QuantumCircuit(1)
qc_hxh.h(0); qc_hxh.x(0); qc_hxh.h(0)
qc_z = QuantumCircuit(1)
qc_z.z(0)
print(f"HXH = Z: {Operator(qc_hxh).equiv(Operator(qc_z))} ✅")
print(f"  HXH matrix: {Operator(qc_hxh).data.real.astype(int)}")

# HZH = X (the converse!)
qc_hzh = QuantumCircuit(1)
qc_hzh.h(0); qc_hzh.z(0); qc_hzh.h(0)
qc_x = QuantumCircuit(1)
qc_x.x(0)
print(f"\nHZH = X: {Operator(qc_hzh).equiv(Operator(qc_x))} ✅")
print(f"  HZH matrix: {Operator(qc_hzh).data.real.astype(int)}")

# Why this matters: Hadamard "converts" between X and Z bases
print("\n📋 Key Insight: Hadamard swaps X ↔ Z under conjugation")
print("   HXH = Z (X gate 'becomes' Z gate in H basis)")
print("   HZH = X (Z gate 'becomes' X gate in H basis)")
print("   This is why H converts between computational and ± bases!")

# %%
# Phase Gates - S, T, P (only affect |1⟩ component)

# S Gate - Phase by π/2
qc_s = QuantumCircuit(1)
qc_s.s(0)
s_matrix = Operator(qc_s).data
print("S Matrix:")
print(s_matrix)

# S† (S-dagger) - Inverse of S
qc_sdg = QuantumCircuit(1)
qc_sdg.sdg(0)
print("\nS† Matrix:")
print(Operator(qc_sdg).data)

# T Gate - Phase by π/4
qc_t = QuantumCircuit(1)
qc_t.t(0)
print("\nT Matrix:")
print(Operator(qc_t).data)

# P(λ) - Arbitrary Phase
qc_p = QuantumCircuit(1)
qc_p.p(np.pi/3, 0)
print("\nP(π/3) Matrix:")
print(Operator(qc_p).data)

# Z reference for comparisons
qc_z_ref = QuantumCircuit(1)
qc_z_ref.z(0)
z_ref_matrix = Operator(qc_z_ref).data

# Verify: S = T² and S² = Z
qc_t2 = QuantumCircuit(1)
qc_t2.t(0)
qc_t2.t(0)
print(f"\n--- Phase Gate Relationships ---")
print(f"T² = S: {np.allclose(Operator(qc_t2).data, s_matrix)} ✅")

qc_s2 = QuantumCircuit(1)
qc_s2.s(0)
qc_s2.s(0)
print(f"S² = Z: {np.allclose(Operator(qc_s2).data, z_ref_matrix)} ✅")

qc_t4 = QuantumCircuit(1)
for _ in range(4):
    qc_t4.t(0)
print(f"T⁴ = Z: {np.allclose(Operator(qc_t4).data, z_ref_matrix)} ✅")

# %% [markdown]
# ---
#
# ## 4. Rotation Gates (RX, RY, RZ)
#
# **Parameterized gates** used in variational algorithms
#
# - **RX(θ)**: Rotation around X-axis
# - **RY(θ)**: Rotation around Y-axis
# - **RZ(θ)**: Rotation around Z-axis

# %%
# Rotation Gates - RX, RY, RZ (parameterized)

theta = np.pi / 4  # 45 degrees

# RX Gate
qc_rx = QuantumCircuit(1)
qc_rx.rx(theta, 0)
print(f"RX(π/4) Matrix:")
print(Operator(qc_rx).data)
print(f"RX(π/4)|0⟩ = {Statevector(qc_rx).data}")

# RY Gate
qc_ry = QuantumCircuit(1)
qc_ry.ry(theta, 0)
print(f"\nRY(π/4) Matrix:")
print(Operator(qc_ry).data)
print(f"RY(π/4)|0⟩ = {Statevector(qc_ry).data}")

# RZ Gate  
qc_rz = QuantumCircuit(1)
qc_rz.rz(theta, 0)
print(f"\nRZ(π/4) Matrix:")
print(Operator(qc_rz).data)
print(f"RZ(π/4)|0⟩ = {Statevector(qc_rz).data}")

# Key rotation angles
print("\n--- Key Rotations ---")
qc_ry_90 = QuantumCircuit(1)
qc_ry_90.ry(np.pi/2, 0)
print(f"RY(π/2)|0⟩ = {Statevector(qc_ry_90).data} (equal superposition)")

qc_ry_180 = QuantumCircuit(1)
qc_ry_180.ry(np.pi, 0)
print(f"RY(π)|0⟩ = {Statevector(qc_ry_180).data} (flip to |1⟩)")

# Verify: RX(π) = X, RY(π) = Y, RZ(π) = Z (up to global phase)
qc_rx_pi = QuantumCircuit(1)
qc_rx_pi.rx(np.pi, 0)
qc_x_ref = QuantumCircuit(1)
qc_x_ref.x(0)
print(f"\nRX(π) ≡ X: {Operator(qc_rx_pi).equiv(Operator(qc_x_ref))} ✅")

# %%
# Probability of finding |0> after RY(π/3) with Bloch sphere visualization
# and theta/phi angles on the Bloch sphere
# Visualize states on the Bloch sphere with angles for RX, RY, RZ rotations

print("=" * 70)
print("Rotation Gate Analysis: RX(π/3), RY(π/3), RZ(π/3)")
print("=" * 70)
# In the geometric representation of qubit using theta and phi angles:
# the angle θ represents rotation from |0⟩ towards |1⟩ (latitude),
# while φ represents rotation around the Z-axis (longitude).
# formula of the state vector in terms of θ and φ:
# |ψ⟩ = cos(θ/2)|0⟩ + e^(iφ)·sin(θ/2)|1⟩
# https://www.protocols.io/view/bsa-the-bloch-sphere-approach-as-a-geometrical-des-bp2l6dkkdvqe/v4

# Visualize RX, RY, RZ rotations on Bloch sphere with angle annotations

print("\n📊 Bloch Sphere Angle Convention:")
print("=" * 70)
print("  θ (theta) - Latitude/Polar angle:")
print("    • Range: 0 to π")
print("    • θ = 0   → North pole (|0⟩)")
print("    • θ = π/2 → Equator (superposition)")
print("    • θ = π   → South pole (|1⟩)")
print("\n  φ (phi) - Longitude/Azimuthal angle:")
print("    • Range: 0 to 2π")
print("    • φ = 0   → Positive X-axis")
print("    • φ = π/2 → Positive Y-axis")
print("    • φ = π   → Negative X-axis")
print("    • φ = 3π/2 → Negative Y-axis")
print("\n  State formula: |ψ⟩ = cos(θ/2)|0⟩ + e^(iφ)·sin(θ/2)|1⟩")

print("\n" + "=" * 70)
print("📐 Geometric Effects of Rotation Gates on |0⟩:")
print("=" * 70)

# RY(θ) - Rotation around Y-axis
print("\n🔵 RY(θ) applied to |0⟩:")
print("  • Rotates in the X-Z plane (around Y-axis)")
print("  • Bloch sphere angle θ_bloch changes from 0 to θ")
print("  • Angle φ_bloch remains 0 (stays in X-Z plane)")
print("  • Geometric formula: |ψ⟩ = cos(θ/2)|0⟩ + sin(θ/2)|1⟩")

# RX(θ) - Rotation around X-axis  
print("\n🔴 RX(θ) applied to |0⟩:")
print("  • Rotates in the Y-Z plane (around X-axis)")
print("  • Bloch sphere angle θ_bloch changes from 0 to θ")
print("  • Angle φ_bloch = -π/2 (moves into Y-Z plane)")
print("  • Geometric formula: |ψ⟩ = cos(θ/2)|0⟩ + e^(i·(-π/2))·sin(θ/2)|1⟩")
print("  •                      = cos(θ/2)|0⟩ - i·sin(θ/2)|1⟩")

# RZ(θ) - Rotation around Z-axis
print("\n🟢 RZ(θ) applied to |0⟩:")
print("  • Rotates around Z-axis (longitude change)")
print("  • Bloch sphere angle θ_bloch remains 0 (stays at north pole)")
print("  • Angle φ_bloch changes by θ")
print("  • Geometric formula: |ψ⟩ = e^(-iθ/2)|0⟩ (global phase only)")
print("  • Note: RZ only affects |1⟩ component, so RZ(θ)|0⟩ = e^(-iθ/2)|0⟩")

print("\n" + "=" * 70)
print("📐 Geometric Effects of Rotation Gates on |1⟩:")
print("=" * 70)

# RY(θ) - Rotation around Y-axis applied to |1⟩
print("\n🔵 RY(θ) applied to |1⟩:")
print("  • Rotates in the X-Z plane (around Y-axis)")
print("  • Starting point: |1⟩ at south pole (θ_bloch = π)")
print("  • Bloch sphere angle θ_bloch changes from π to π-θ")
print("  • Angle φ_bloch = π (stays in X-Z plane, negative side)")
print("  • Geometric formula: |ψ⟩ = sin(θ/2)|0⟩ + cos(θ/2)|1⟩")

# RX(θ) - Rotation around X-axis applied to |1⟩
print("\n🔴 RX(θ) applied to |1⟩:")
print("  • Rotates in the Y-Z plane (around X-axis)")
print("  • Starting point: |1⟩ at south pole (θ_bloch = π)")
print("  • Bloch sphere angle θ_bloch changes from π to π-θ")
print("  • Angle φ_bloch = π/2 (moves into Y-Z plane)")
print("  • Geometric formula: |ψ⟩ = sin(θ/2)|0⟩ + e^(i·π/2)·cos(θ/2)|1⟩")
print("  •                      = sin(θ/2)|0⟩ + i·cos(θ/2)|1⟩")

# RZ(θ) - Rotation around Z-axis applied to |1⟩
print("\n🟢 RZ(θ) applied to |1⟩:")
print("  • Rotates around Z-axis (longitude change)")
print("  • Bloch sphere angle θ_bloch remains π (stays at south pole)")
print("  • Angle φ_bloch changes by θ")
print("  • Geometric formula: |ψ⟩ = e^(iθ/2)|1⟩")
print("  • Note: RZ(θ)|1⟩ = e^(iθ/2)|1⟩ (phase factor on |1⟩)")

print("\n" + "=" * 70)
print("Summary of Geometric Formulas:")
print("=" * 70)
print("Applied to |0⟩:")
print("  RX(θ)|0⟩ = cos(θ/2)|0⟩ - i·sin(θ/2)|1⟩            [φ = -π/2]")
print("  RY(θ)|0⟩ = cos(θ/2)|0⟩ + sin(θ/2)|1⟩              [φ = 0]")
print("  RZ(θ)|0⟩ = e^(-iθ/2)|0⟩                           [global phase]")
print("\nApplied to |1⟩:")
print("  RX(θ)|1⟩ = sin(θ/2)|0⟩ + i·cos(θ/2)|1⟩            [φ = π/2]")
print("  RY(θ)|1⟩ = sin(θ/2)|0⟩ + cos(θ/2)|1⟩              [φ = π]")
print("  RZ(θ)|1⟩ = e^(iθ/2)|1⟩                            [phase on |1⟩]")

print("\n" + "=" * 70)
print("✅ Verification with θ = π/3:")
print("=" * 70)

# %% [markdown]
# ---
#
# ## 5. Universal U Gate
#
# **Can represent ANY single-qubit gate!**
#
# U(θ, φ, λ) with three parameters

# %%
# Universal U Gate and Identity

# U(θ, φ, λ) - Can represent ANY single-qubit gate
theta, phi, lam = np.pi/2, np.pi/4, np.pi/6
qc_u = QuantumCircuit(1)
qc_u.u(theta, phi, lam, 0)
print(f"U(θ={theta:.4f}, φ={phi:.4f}, λ={lam:.4f}) Matrix:")
print(Operator(qc_u).data)

# Express common gates with U
print("\n--- Gate Equivalences with U ---")

# H = U(π/2, 0, π)
qc_h_u = QuantumCircuit(1)
qc_h_u.u(np.pi/2, 0, np.pi, 0)
print(f"H = U(π/2, 0, π)")

# X = U(π, 0, π)
qc_x_u = QuantumCircuit(1)
qc_x_u.u(np.pi, 0, np.pi, 0)
print(f"X = U(π, 0, π)")

# Identity Gate - Do-nothing gate
qc_i = QuantumCircuit(1)
qc_i.id(0)
print(f"\nI Matrix:")
print(Operator(qc_i).data)
print(f"I|0⟩ = {Statevector(qc_i).data} (unchanged)")

# %%
gates = {
    'I': lambda qc: qc.id(0),
    'X': lambda qc: qc.x(0),
    'Y': lambda qc: qc.y(0),
    'Z': lambda qc: qc.z(0),
    'H': lambda qc: qc.h(0),
    'S': lambda qc: qc.s(0),
    'T': lambda qc: qc.t(0),
    'S†': lambda qc: qc.sdg(0),
    'T†': lambda qc: qc.tdg(0),
}

print("Gate | State after applying to |0⟩")
print("=" * 70)

for gate_name, gate_func in gates.items():
    qc = QuantumCircuit(1)
    gate_func(qc)
    state = Statevector(qc)
    
    amp0 = f"{state.data[0]:.4f}"
    amp1 = f"{state.data[1]:.4f}"
    print(f"{gate_name:4} | [{amp0:>12}, {amp1:>12}]")

print("\n" + "=" * 70)
print("Rotation Gates (θ = π/4):")
print("=" * 70)

for gate_name, gate_func in [
    ('RX(π/4)', lambda qc: qc.rx(np.pi/4, 0)),
    ('RY(π/4)', lambda qc: qc.ry(np.pi/4, 0)),
    ('RZ(π/4)', lambda qc: qc.rz(np.pi/4, 0)),
]:
    qc = QuantumCircuit(1)
    gate_func(qc)
    state = Statevector(qc)
    amp0 = f"{state.data[0]:.4f}"
    amp1 = f"{state.data[1]:.4f}"
    print(f"{gate_name:8} | [{amp0:>12}, {amp1:>12}]")

# %%
# TRAP: Gate Commutativity (order matters!)

print("⚠️ TRAP: Gate Order - Does it matter?")
print("=" * 60)

# NON-COMMUTATIVE: X and Z (ANTICOMMUTE!)
qc_xz = QuantumCircuit(1)
qc_xz.x(0)
qc_xz.z(0)
qc_zx = QuantumCircuit(1)
qc_zx.z(0)
qc_zx.x(0)
print(f"\n❌ X·Z|0⟩ = {Statevector(qc_xz).data}")
print(f"   Z·X|0⟩ = {Statevector(qc_zx).data}")
print(f"   X and Z commute: {np.allclose(Statevector(qc_xz).data, Statevector(qc_zx).data)} → ANTICOMMUTE!")

# NON-COMMUTATIVE: H and S
qc_hs = QuantumCircuit(1)
qc_hs.h(0)
qc_hs.s(0)
qc_sh = QuantumCircuit(1)
qc_sh.s(0)
qc_sh.h(0)
print(f"\n❌ H·S|0⟩ = {Statevector(qc_hs).data}")
print(f"   S·H|0⟩ = {Statevector(qc_sh).data}")
print(f"   H and S commute: {np.allclose(Statevector(qc_hs).data, Statevector(qc_sh).data)}")

# COMMUTATIVE: Phase gates (Z, S, T) - all diagonal
qc_st = QuantumCircuit(1)
qc_st.s(0)
qc_st.t(0)
qc_ts = QuantumCircuit(1)
qc_ts.t(0)
qc_ts.s(0)
print(f"\n✅ S·T = T·S: {Operator(qc_st).equiv(Operator(qc_ts))} (both diagonal/phase gates)")

print("\n📋 RULE: Phase gates (Z,S,T,P) commute with each other!")
print("   Different qubits → ALWAYS commute")
print("   Same gate twice → ALWAYS commute (XX=I)")
print("   Pauli X,Y,Z → ANTICOMMUTE pairwise!")

# %% [markdown]
# ---
#
# ## 7. Pauli Class (`qiskit.quantum_info.Pauli`)
#
# > ⚠️ Different from Pauli gates (`qc.x()`, `qc.y()`, `qc.z()`)!

# %%
# Pauli Class - qiskit.quantum_info.Pauli (NOT same as qc.x/y/z gates!)

from qiskit.quantum_info import Pauli

# Creating Pauli objects from string labels (RIGHT-TO-LEFT qubit ordering)
X = Pauli('X')
Y = Pauli('Y')
Z = Pauli('Z')
I = Pauli('I')

print("Single-qubit Paulis:")
print(f"X: {X.to_label()}, num_qubits: {X.num_qubits}")

# Multi-qubit: 'XYZ' = X⊗Y⊗Z (X on q2, Y on q1, Z on q0)
p_multi = Pauli('XYZ')
print(f"\n'XYZ': {p_multi.to_label()}, num_qubits: {p_multi.num_qubits}")

# Phase prefixes: +1 (none), +i ('i'), -1 ('-'), -i ('-i')
p_phases = [Pauli('X'), Pauli('iX'), Pauli('-X'), Pauli('-iX')]
print("\nPhase notation:")
for p in p_phases:
    print(f"  phase={p.phase}: {p.to_label()}")

# Key attributes: x, z arrays (binary representation)
p = Pauli('IXYZ')
print(f"\n'IXYZ' binary: x={p.x}, z={p.z}")
print("  (X: x=1,z=0 | Y: x=1,z=1 | Z: x=0,z=1 | I: x=0,z=0)")

# %%
# Pauli Commutativity & Composition

X, Y, Z = Pauli('X'), Pauli('Y'), Pauli('Z')

# Same Paulis ALWAYS commute
print("=== Commutativity ===")
print(f"X.commutes(X): {X.commutes(X)} ✅")

# Different Paulis on SAME qubit ANTICOMMUTE
print(f"X.commutes(Z): {X.commutes(Z)} ❌")
print(f"X.anticommutes(Z): {X.anticommutes(Z)} ✅")

# Different qubits ALWAYS commute
XI = Pauli('XI')
IZ = Pauli('IZ')
print(f"'XI'.commutes('IZ'): {XI.commutes(IZ)} ✅ (different qubits)")

# Pauli multiplication with @ operator (compose)
print("\n=== Composition: @ operator (XY=iZ, YZ=iX, ZX=iY) ===")
print(f"X @ Y = {(X @ Y).to_label()}")  # iZ
print(f"Y @ Z = {(Y @ Z).to_label()}")  # iX
print(f"Z @ X = {(Z @ X).to_label()}")  # iY
print(f"Y @ X = {(Y @ X).to_label()}")  # -iZ (reverse = negative)

# Self-multiplication: P² = I
print(f"\nX @ X = {(X @ X).to_label()}")  # I
print(f"Y @ Y = {(Y @ Y).to_label()}")  # I

# tensor() - Tensor product with ^ operator
print(f"\n=== Tensor Product: ^ operator ===")
print(f"X ^ Z = X.tensor(Z) = {(X ^ Z).to_label()}")  # XZ (X on higher qubit)
print(f"Z ^ X = Z.tensor(X) = {(Z ^ X).to_label()}")  # ZX (order matters!)
print(f"X.tensor(Y).tensor(Z) = {X.tensor(Y).tensor(Z).to_label()}")  # XYZ

# expand() - Add identities to extend to n qubits
print(f"\n=== Expand: Add Identities ===")
print(f"X.expand(2) = {X.expand(2).to_label()}")  # XI (X on qubit 1, I on qubit 0)
print(f"X.expand(3) = {X.expand(3).to_label()}")  # XII
print(f"Pauli('XY').expand(4) = {Pauli('XY').expand(4).to_label()}")  # XYII

# %%
# Pauli Conversions and Circuit Integration

from qiskit.circuit.library import HGate

X = Pauli('X')
Z = Pauli('Z')

# to_matrix() - Get numpy matrix
print("X.to_matrix():")
print(X.to_matrix())

# to_instruction() - Add to circuit
qc = QuantumCircuit(2)
qc.append(Pauli('XY').to_instruction(), [0, 1])
print("\nCircuit with XY Pauli:")
print(qc.draw())

# evolve() - Pauli transformation under gates (U·P·U†)
H = HGate()
print(f"\n=== evolve(): Gate Conjugation ===")
print(f"H·X·H† = {X.evolve(H).to_label()}")  # Z
print(f"H·Z·H† = {Z.evolve(H).to_label()}")  # X

# %% [markdown]
# ---
#
# ## ⚠️ CRITICAL TRAP: Pauli String Ordering (RIGHT-TO-LEFT)
#
# > **Exam trap**: `Pauli('XYZ')` means X on qubit 2, Y on qubit 1, Z on qubit 0!
#
# ```python
# Pauli('XYZ')  # X⊗Y⊗Z where:
#               # Index 0 (rightmost 'Z') → qubit 0
#               # Index 1 (middle 'Y')    → qubit 1
#               # Index 2 (leftmost 'X')  → qubit 2
# ```

# %%
# ⚠️ CRITICAL TRAP: Pauli String Ordering is RIGHT-TO-LEFT!
from qiskit.quantum_info import Pauli

print("=" * 60)
print("⚠️ TRAP: Pauli String Ordering (RIGHT-TO-LEFT)")
print("=" * 60)

# Create Pauli 'XYZ' - what does each character mean?
p = Pauli('XYZ')
print(f"\nPauli('XYZ') interpretation:")
print(f"  String 'XYZ' → X on q2, Y on q1, Z on q0")
print(f"  Rightmost char = qubit 0, Leftmost = highest qubit")

# Verify by checking which qubit gets which gate
# Create circuit manually and compare
from qiskit import QuantumCircuit
from qiskit.quantum_info import Operator

# Manual: X on q2, Y on q1, Z on q0
qc_manual = QuantumCircuit(3)
qc_manual.z(0)  # Z on qubit 0 (rightmost in string)
qc_manual.y(1)  # Y on qubit 1 (middle)
qc_manual.x(2)  # X on qubit 2 (leftmost in string)

# From Pauli
qc_pauli = QuantumCircuit(3)
qc_pauli.append(Pauli('XYZ').to_instruction(), [0, 1, 2])

# Verify they're equivalent
print(f"\nManual (Z on q0, Y on q1, X on q2) == Pauli('XYZ'): ", end="")
print(Operator(qc_manual).equiv(Operator(qc_pauli)), "✅")

# Common mistake demonstration
print("\n❌ WRONG interpretation:")
print("   'XYZ' does NOT mean X on q0, Y on q1, Z on q2!")

# Show the trap with 'XI' - which qubit gets X?
p2 = Pauli('XI')
print(f"\n'XI' (2 qubits): X on qubit 1, I on qubit 0")
print(f"   I is rightmost → I on q0")
print(f"   X is leftmost  → X on q1")

# Verify
qc_xi = QuantumCircuit(2)
qc_xi.x(1)  # X on qubit 1 (NOT qubit 0!)
qc_pauli_xi = QuantumCircuit(2)
qc_pauli_xi.append(Pauli('XI').to_instruction(), [0, 1])
print(f"   Verification: {Operator(qc_xi).equiv(Operator(qc_pauli_xi))} ✅")

print("\n📋 RULE: Read Pauli strings from RIGHT to LEFT for qubit assignment!")
print("   Pauli('ABC') → A on q2, B on q1, C on q0")

# %%
# Pauli Class - expand() method (extend Pauli to more qubits with identities)
from qiskit.quantum_info import Pauli

print("Pauli.expand(num_qubits) - Extend with Identity padding")
print("=" * 60)

# Single qubit X expanded to 3 qubits
X = Pauli('X')
print(f"Pauli('X').expand(3) = {X.expand(3).to_label()}")
print("  → XII (X on highest qubit, I on others)")

# Single qubit Z expanded  
Z = Pauli('Z')
print(f"\nPauli('Z').expand(3) = {Z.expand(3).to_label()}")
print("  → ZII (Z on highest qubit)")

# Multi-qubit expanded
XY = Pauli('XY')
print(f"\nPauli('XY').expand(4) = {XY.expand(4).to_label()}")
print("  → XYII (original on higher qubits, I padding on lower)")

# Key insight: expand adds identities on the RIGHT (lower qubits)
print("\n📋 RULE: expand(n) pads with I on the right (lower qubit indices)")
print("   Pauli('P').expand(n) → P with (n - num_qubits) I's appended right")

# %% [markdown]
# ---
#
# ## 8. Code Challenges

# %%
# 🧪 Code Challenges - Test Yourself!

print("=" * 60)
print("CHALLENGE 1: What is H-X-H|0⟩?")
print("=" * 60)
qc1 = QuantumCircuit(1)
qc1.h(0)
qc1.x(0)
qc1.h(0)
result1 = Statevector(qc1)
print(f"HXH|0⟩ = {result1.data}")
print(f"Since HXH = Z and Z|0⟩ = |0⟩ → Answer: |0⟩ ✅")

print("\n" + "=" * 60)
print("CHALLENGE 2: Which gates commute - X&Z or S&T?")
print("=" * 60)
# X and Z
qc_xz = QuantumCircuit(1)
qc_xz.x(0); qc_xz.z(0)
qc_zx = QuantumCircuit(1)
qc_zx.z(0); qc_zx.x(0)
print(f"X·Z = Z·X? {np.allclose(Statevector(qc_xz).data, Statevector(qc_zx).data)} ❌")

# S and T
qc_st = QuantumCircuit(1)
qc_st.s(0); qc_st.t(0)
qc_ts = QuantumCircuit(1)
qc_ts.t(0); qc_ts.s(0)
print(f"S·T = T·S? {Operator(qc_st).equiv(Operator(qc_ts))} ✅")
print("Answer: S and T commute (both phase gates)")

print("\n" + "=" * 60)
print("CHALLENGE 3: What gate creates |+⟩ from |0⟩?")
print("=" * 60)
qc3 = QuantumCircuit(1)
qc3.h(0)
print(f"H|0⟩ = {Statevector(qc3).data}")
print("Answer: Hadamard (H) gate ✅")

# %% [markdown]
# ---
#
# ## ✅ Summary
#
# 📖 **See [README.md](README.md) for concepts, mnemonics, and theory**
#
# This CODE LAB covered:
# - Pauli gates (X, Y, Z) - basis gates
# - Hadamard (H) - superposition creator
# - Phase gates (S, T, P) - modify phase of |1⟩
# - Rotation gates (RX, RY, RZ) - parameterized
# - U gate - any single-qubit gate
# - Pauli class - algebraic operations
# - Gate commutativity (⚠️ TRAP topic!)
